# %%
import numpy as np
import pandas as pd

# %%
data =pd.read_csv("GFG_FINAL.csv")
df=pd.DataFrame(data)
print(df.head(1))
df.shape
# Out:
#                                              Summary         Issue key  \
# 0  Sourcetree repository tab width automatically ...  SRCTREEWIN-14221
#
#    Issue id Issue Type              Status Project key  \
# 0   1949800        Bug  Short Term Backlog  SRCTREEWIN
#
#              Project name Project type Project lead  Project description  ...  \
# 0  Sourcetree for Windows     software       rgomis                  NaN  ...
#
#   Comment.75 Comment.76 Comment.77 Comment.78 Comment.79 Comment.80  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Comment.81 Comment.82 Comment.83 Comment.84
# 0        NaN        NaN        NaN        NaN
#
# [1 rows x 491 columns]
# (49000, 491)

# %%
df.drop(columns="Component/s")
# Out:
#                                                  Summary         Issue key  \
# 0      Sourcetree repository tab width automatically ...  SRCTREEWIN-14221
# 1      Stashes don't show untracked files when clicki...  SRCTREEWIN-14215
# 2                            Beyond compare not starting  SRCTREEWIN-14211
# 3      Displaying all changes between hash1 and hash2...  SRCTREEWIN-14210
# 4      Displaying all changes between hash1 and hash2...  SRCTREEWIN-14209
# ...                                                  ...               ...
# 48995  The adjustable border line between staged and ...  SRCTREEWIN-12341
# 48996  Git flow not automatically branching from corr...  SRCTREEWIN-12338
# 48997  Cherry-pick does not provide an option to push...  SRCTREEWIN-12337
# 48998                                  Names for patches  SRCTREEWIN-12336
# 48999           Code scroll not proper in horizontal way  SRCTREEWIN-12334
#
#        Issue id  Issue Type              Status Project key  \
# ...

# %%
# !git --version
# Out:
# git version 2.51.0.windows.2

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A00E-56C0
#
#  Directory of C:\Users\tiwar
#
# 12-10-2025  19:25    <DIR>          .
# 30-01-2025  20:12    <DIR>          ..
# 12-04-2025  23:02    <DIR>          .anaconda
# 06-05-2023  21:25    <DIR>          .android
# 13-09-2025  23:28    <DIR>          .cache
# 24-08-2025  08:49    <DIR>          .conda
# 12-04-2025  23:07               146 .condarc
# 12-04-2025  23:02    <DIR>          .continuum
# 24-11-2022  15:16    <DIR>          .dotnet
# 12-10-2025  16:45                59 .gitconfig
# 22-10-2023  11:01    <DIR>          .idea
# 25-02-2023  12:47    <DIR>          .idlerc
# 12-10-2025  16:20    <DIR>          .ipynb_checkpoints
# 06-04-2024  14:59    <DIR>          .ipython
# 06-04-2024  15:16    <DIR>          .jupyter
# 22-04-2025  09:45    <DIR>          .keras
# 22-04-2025  09:45    <DIR>          .matplotlib
# 28-09-2025  21:19    <DIR>          .streamlit
# ...

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A00E-56C0
#
#  Directory of C:\Users\tiwar
#
# 12-10-2025  21:36    <DIR>          .
# 30-01-2025  20:12    <DIR>          ..
# 12-04-2025  23:02    <DIR>          .anaconda
# 06-05-2023  21:25    <DIR>          .android
# 13-09-2025  23:28    <DIR>          .cache
# 24-08-2025  08:49    <DIR>          .conda
# 12-04-2025  23:07               146 .condarc
# 12-04-2025  23:02    <DIR>          .continuum
# 24-11-2022  15:16    <DIR>          .dotnet
# 12-10-2025  16:45                59 .gitconfig
# 22-10-2023  11:01    <DIR>          .idea
# 25-02-2023  12:47    <DIR>          .idlerc
# 12-10-2025  16:20    <DIR>          .ipynb_checkpoints
# 06-04-2024  14:59    <DIR>          .ipython
# 06-04-2024  15:16    <DIR>          .jupyter
# 22-04-2025  09:45    <DIR>          .keras
# 22-04-2025  09:45    <DIR>          .matplotlib
# 28-09-2025  21:19    <DIR>          .streamlit
# ...

# %%
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/vahbuna91/AI_Task_Management_System.git
# !git push -u origin main
# Out:
# Initialized empty Git repository in C:/Users/tiwar/.git/
# fatal: pathspec 'README.md' did not match any files
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.anaconda/
# 	.android/
# 	.cache/
# 	.conda/
# 	.condarc
# 	.continuum/
# 	.dotnet/
# 	.gitconfig
# 	.idea/
# 	.idlerc/
# 	.ipynb_checkpoints/
# 	.ipython/
# 	.jupyter/
# 	.keras/
# 	.matplotlib/
# 	.streamlit/
# 	.vscode/
# 	3rd year Result.csv
# 	AI task management system.ipynb
# 	AI_Task_Management_System/
# 	All Pattern program.ipynb
# 	Anubhav Numpy.ipynb
# 	Anubhav photo.jpg
# 	Apnacollege.ipynb
# 	AppData/
# 	B.Tech_3rd_Year_Result_2024-25.xlsx
# 	B.tech  3rd Year Result.xlsx
# 	Cancer Detection Project.ipynb
# 	Contacts/
# 	Desktop/
# 	Dictionary.ipynb
# 	Downloads/
# 	Employee.csv
# 	Favorites/
# 	First Task.ipynb
# 	First Test.ipynb
# 	Function.ipynb
# 	GFG_FINAL.csv
# 	GreatLearning.ipynb
# 	Lamdafunction.ipynb
# 	Links/
# ...

# %%
# !cd C:\Users\tiwar
# !rmdir /s /q .git

# %%
cd C:\Users\tiwar\AI_Task_Management_System
# Out:
# C:\Users\tiwar\AI_Task_Management_System

# %%
# !git init
# !git add .
# !git commit -m "first commit"
# Out:
# Reinitialized existing Git repository in C:/Users/tiwar/AI_Task_Management_System/.git/
# On branch main
# nothing to commit, working tree clean

# %%
# !git branch -M main
# !git remote add origi!n https://github.com/vahbuna91/AI_Task_Management_System.git
# !git push -u origin main

# %%
# !git remote remove origin
# !git remote add origin https://github.com/vabhanu91/AI_Task_Management_System.git

# %%
# Step 1: सही directory में जाएँ
# !cd C:\Users\tiwar\AI_Task_Management_System

# Step 2: यदि गलत remote जुड़ा है, हटाएँ और सही जोड़ें
# !git remote remove origin
# !git remote add origin https://github.com/vabhanu91/AI_Task_Management_System.git

# Step 3: फाइलें जोड़ें और पहला commit करें
# !git add .
# !git commit -m "first commit"

# Step 4: main branch बनाएँ और push करें
# !git branch -M main
# !git push -u origin main
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/vabhanu91/AI_Task_Management_System.git'

# %%
cd C:\Users\tiwar\AI_Task_Management_System
# Out:
# C:\Users\tiwar\AI_Task_Management_System

# %%
# !git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !echo "# AI_Task_Management_System" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/vahbuna91/AI_Task_Management_System.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in C:/Users/tiwar/AI_Task_Management_System/.git/
# [main 11805cb] first commit
#  1 file changed, 1 insertion(+)
# error: remote origin already exists.

# %%
git remote add origin https://github.com/vahbuna91/AI_Task_Management_System.git
git branch -M main
git push -u origin main
